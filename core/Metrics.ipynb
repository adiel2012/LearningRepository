# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
import tensorflow.keras.utils as np_utils
import random

# %%
num_patterns = 200
num_features = 2
num_classes = 2
mu, sigma = 0, 0.5

Xred = np.random.normal(mu, sigma, (num_patterns, num_features)) + np.array([0.5, 0.5])
Yred = np.zeros(num_patterns, dtype=int)
Xblue = np.random.normal(mu, sigma,(num_patterns, num_features)) + np.array([-0.5, -0.5])
Yblue = np.ones(num_patterns, dtype=int) * 1
X = np.concatenate((Xred, Xblue), axis=0)
num_patterns = num_patterns * num_classes
Y = np.concatenate((Yred, Yblue), axis=0)

#standarize
Y_hot = np.zeros((Y.size, Y.max()+1))
Y_hot[np.arange(Y.size),Y] = 1
Y = np.reshape(Y, (-1,1))

# %%
print(X.shape)
plt.scatter(X[0:int(num_patterns/2),0], X[0:int(num_patterns/2),1], color='red')
plt.scatter(X[int(num_patterns/2): int(2*num_patterns/2),0], X[int(num_patterns/2): int(2*num_patterns/2),1], color='blue')
# Out:
# (400, 2)

# %%
X = 2*((X - X.min(0)) / X.ptp(0)) -1
plt.scatter(X[0:int(num_patterns/2),0], X[0:int(num_patterns/2),1], color='red')
plt.scatter(X[int(num_patterns/2): int(2*num_patterns/2),0], X[int(num_patterns/2): int(2*num_patterns/2),1], color='blue')

# %%
percent = 0.8
n = int(percent * num_patterns) 
indexes = [i for i in range(num_patterns)]
random.shuffle(indexes)

index_train = indexes[0:n]
index_test = indexes[n::]

y_train = Y[index_train, :]
y_test = Y[index_test, :]
X_train = X[index_train, :]
X_test = X[index_test, :]

batch_size = 10
epochs = 50

def build_logistic_model(input_dim, output_dim):
    model = Sequential()
    model.add(Dense(output_dim, input_dim=num_features, activation='softmax'))

    return model

# convert class vectors to binary class matrices
Y_train = np_utils.to_categorical(y_train, num_classes)
Y_test = np_utils.to_categorical(y_test, num_classes)

model = build_logistic_model(num_features, num_classes)

model.summary()

# compile the model
model.compile(optimizer='sgd', loss='binary_crossentropy', metrics=['accuracy'])
history = model.fit(X_train, Y_train,
                    batch_size=batch_size, epochs=epochs,
                    verbose=1, validation_data=(X_test, Y_test))
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 2)                 6
# =================================================================
# Total params: 6
# Trainable params: 6
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 32/32 [==============================] - 0s 10ms/step - loss: 0.9810 - accuracy: 0.1187 - val_loss: 0.9308 - val_accuracy: 0.1625
# Epoch 2/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9349 - accuracy: 0.1375 - val_loss: 0.8893 - val_accuracy: 0.1500
# Epoch 3/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.8918 - accuracy: 0.1688 - val_loss: 0.8505 - val_accuracy: 0.1500
# Epoch 4/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.8515 - accuracy: 0.1906 - val_loss: 0.8144 - val_accuracy: 0.1750
# Epoch 5/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.8142 - accuracy: 0.2313 - val_loss: 0.7807 - val_accuracy: 0.1875
# Epoch 6/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.7797 - accuracy: 0.2625 - val_loss: 0.7494 - val_accuracy: 0.2500
# Epoch 7/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.7476 - accuracy: 0.3313 - val_loss: 0.7203 - val_accuracy: 0.4250
# Epoch 8/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.7178 - accuracy: 0.4000 - val_loss: 0.6933 - val_accuracy: 0.5625
# Epoch 9/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6903 - accuracy: 0.5250 - val_loss: 0.6683 - val_accuracy: 0.6000
# Epoch 10/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6648 - accuracy: 0.6562 - val_loss: 0.6450 - val_accuracy: 0.7125
# Epoch 11/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6414 - accuracy: 0.7469 - val_loss: 0.6234 - val_accuracy: 0.8250
# Epoch 12/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6194 - accuracy: 0.8344 - val_loss: 0.6033 - val_accuracy: 0.8625
# Epoch 13/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5992 - accuracy: 0.8719 - val_loss: 0.5846 - val_accuracy: 0.8750
# Epoch 14/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5803 - accuracy: 0.8813 - val_loss: 0.5673 - val_accuracy: 0.9250
# Epoch 15/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.5629 - accuracy: 0.8938 - val_loss: 0.5511 - val_accuracy: 0.9375
# Epoch 16/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5467 - accuracy: 0.9000 - val_loss: 0.5360 - val_accuracy: 0.9375
# Epoch 17/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5318 - accuracy: 0.9031 - val_loss: 0.5218 - val_accuracy: 0.9375
# Epoch 18/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5177 - accuracy: 0.9187 - val_loss: 0.5086 - val_accuracy: 0.9500
# Epoch 19/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5045 - accuracy: 0.9156 - val_loss: 0.4962 - val_accuracy: 0.9500
# Epoch 20/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4923 - accuracy: 0.9187 - val_loss: 0.4845 - val_accuracy: 0.9500
# Epoch 21/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4809 - accuracy: 0.9250 - val_loss: 0.4736 - val_accuracy: 0.9500
# Epoch 22/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4702 - accuracy: 0.9250 - val_loss: 0.4633 - val_accuracy: 0.9375
# Epoch 23/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4602 - accuracy: 0.9250 - val_loss: 0.4536 - val_accuracy: 0.9375
# Epoch 24/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4507 - accuracy: 0.9312 - val_loss: 0.4445 - val_accuracy: 0.9375
# Epoch 25/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4418 - accuracy: 0.9312 - val_loss: 0.4359 - val_accuracy: 0.9375
# Epoch 26/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4334 - accuracy: 0.9312 - val_loss: 0.4277 - val_accuracy: 0.9375
# Epoch 27/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4255 - accuracy: 0.9281 - val_loss: 0.4200 - val_accuracy: 0.9375
# Epoch 28/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4181 - accuracy: 0.9281 - val_loss: 0.4126 - val_accuracy: 0.9375
# Epoch 29/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4110 - accuracy: 0.9281 - val_loss: 0.4057 - val_accuracy: 0.9375
# Epoch 30/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4043 - accuracy: 0.9344 - val_loss: 0.3990 - val_accuracy: 0.9375
# Epoch 31/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3980 - accuracy: 0.9344 - val_loss: 0.3927 - val_accuracy: 0.9375
# Epoch 32/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3919 - accuracy: 0.9375 - val_loss: 0.3867 - val_accuracy: 0.9375
# Epoch 33/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3863 - accuracy: 0.9344 - val_loss: 0.3810 - val_accuracy: 0.9375
# Epoch 34/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3808 - accuracy: 0.9344 - val_loss: 0.3756 - val_accuracy: 0.9375
# Epoch 35/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3757 - accuracy: 0.9312 - val_loss: 0.3703 - val_accuracy: 0.9250
# Epoch 36/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3707 - accuracy: 0.9344 - val_loss: 0.3653 - val_accuracy: 0.9250
# Epoch 37/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3660 - accuracy: 0.9344 - val_loss: 0.3605 - val_accuracy: 0.9250
# Epoch 38/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3615 - accuracy: 0.9344 - val_loss: 0.3559 - val_accuracy: 0.9250
# Epoch 39/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3572 - accuracy: 0.9344 - val_loss: 0.3515 - val_accuracy: 0.9250
# Epoch 40/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3531 - accuracy: 0.9344 - val_loss: 0.3473 - val_accuracy: 0.9250
# Epoch 41/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3492 - accuracy: 0.9344 - val_loss: 0.3432 - val_accuracy: 0.9250
# Epoch 42/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3453 - accuracy: 0.9344 - val_loss: 0.3393 - val_accuracy: 0.9250
# Epoch 43/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3417 - accuracy: 0.9344 - val_loss: 0.3355 - val_accuracy: 0.9250
# Epoch 44/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3383 - accuracy: 0.9344 - val_loss: 0.3319 - val_accuracy: 0.9250
# Epoch 45/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3349 - accuracy: 0.9344 - val_loss: 0.3284 - val_accuracy: 0.9250
# Epoch 46/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3318 - accuracy: 0.9312 - val_loss: 0.3251 - val_accuracy: 0.9250
# Epoch 47/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3286 - accuracy: 0.9312 - val_loss: 0.3218 - val_accuracy: 0.9250
# Epoch 48/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3256 - accuracy: 0.9312 - val_loss: 0.3187 - val_accuracy: 0.9250
# Epoch 49/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3228 - accuracy: 0.9312 - val_loss: 0.3156 - val_accuracy: 0.9250
# Epoch 50/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3200 - accuracy: 0.9312 - val_loss: 0.3127 - val_accuracy: 0.9250

# %%
model.predict(X_test)
pred = model.predict(np.array(X_test))
predictions = np.argmax(pred, axis=-1)

inference = np.concatenate((np.reshape(pred, (-1,num_classes)), np.reshape(predictions, (-1,1)), y_test), axis=1)
#print(inference)
inference_sorted = np.array(sorted(inference, key=lambda a_entry: 1.0/a_entry[1]))
print(inference_sorted)
num_test_patterns = inference_sorted.shape[0]
# Out:
# [[0.05885348 0.94114649 1.         1.        ]
#  [0.07513829 0.92486173 1.         1.        ]
#  [0.08895326 0.91104674 1.         1.        ]
#  [0.10352343 0.89647657 1.         1.        ]
#  [0.11846555 0.88153446 1.         1.        ]
#  [0.12755117 0.87244886 1.         1.        ]
#  [0.14330682 0.85669321 1.         1.        ]
#  [0.14383885 0.85616118 1.         1.        ]
#  [0.14587808 0.85412192 1.         1.        ]
#  [0.15985277 0.84014726 1.         1.        ]
#  [0.17677172 0.8232283  1.         1.        ]
#  [0.17849892 0.82150108 1.         1.        ]
#  [0.19225663 0.80774337 1.         1.        ]
#  [0.19671974 0.80328023 1.         1.        ]
#  [0.1996379  0.80036211 1.         1.        ]
#  [0.20259643 0.79740363 1.         1.        ]
#  [0.21756828 0.78243172 1.         1.        ]
#  [0.2222967  0.77770329 1.         1.        ]
#  [0.2692883  0.7307117  1.         1.        ]
#  [0.28316832 0.71683168 1.         1.        ]
#  [0.28809038 0.71190959 1.         1.        ]
#  [0.29596597 0.70403403 1.         1.        ]
#  [0.29789665 0.70210338 1.         1.        ]
#  [0.30270216 0.69729781 1.         1.        ]
#  [0.31137007 0.68862993 1.         1.        ]
#  [0.3130255  0.68697453 1.         1.        ]
#  [0.31671798 0.68328202 1.         1.        ]
#  [0.32344472 0.67655534 1.         1.        ]
#  [0.3284418  0.6715582  1.         1.        ]
#  [0.3362388  0.66376126 1.         1.        ]
#  [0.35816932 0.64183068 1.         1.        ]
#  [0.37026799 0.62973195 1.         1.        ]
#  [0.37204441 0.62795556 1.         1.        ]
#  [0.43048197 0.56951797 1.         0.        ]
#  [0.46433651 0.53566349 1.         0.        ]
#  [0.48889133 0.5111087  1.         0.        ]
#  [0.49557629 0.50442374 1.         1.        ]
#  [0.49636015 0.50363982 1.         0.        ]
#  [0.52058595 0.47941399 0.         1.        ]
#  [0.53913224 0.46086776 0.         0.        ]
#  [0.55047399 0.44952607 0.         0.        ]
#  [0.55651933 0.4434807  0.         0.        ]
#  [0.56020051 0.43979952 0.         1.        ]
#  [0.5822466  0.41775337 0.         0.        ]
#  [0.60138822 0.39861175 0.         0.        ]
#  [0.61668944 0.38331059 0.         0.        ]
#  [0.62604541 0.37395453 0.         0.        ]
#  [0.63956892 0.36043102 0.         0.        ]
#  [0.67238569 0.32761428 0.         0.        ]
#  [0.69704437 0.3029556  0.         0.        ]
#  [0.70414668 0.29585332 0.         0.        ]
#  [0.71076143 0.28923863 0.         0.        ]
#  [0.71637291 0.28362703 0.         0.        ]
#  [0.72947639 0.27052355 0.         0.        ]
#  [0.7363342  0.26366583 0.         0.        ]
#  [0.7414     0.25860003 0.         0.        ]
#  [0.75265408 0.24734598 0.         0.        ]
#  [0.76490384 0.23509614 0.         0.        ]
#  [0.78740185 0.21259813 0.         0.        ]
#  [0.79219353 0.20780645 0.         0.        ]
#  [0.79355079 0.20644926 0.         0.        ]
#  [0.80696177 0.19303821 0.         0.        ]
#  [0.82302338 0.1769767  0.         0.        ]
#  [0.82422698 0.17577302 0.         0.        ]
#  [0.83949262 0.1605074  0.         0.        ]
#  [0.83977616 0.1602239  0.         0.        ]
#  [0.84652621 0.15347385 0.         0.        ]
#  [0.84709781 0.15290214 0.         0.        ]
#  [0.85276991 0.14723007 0.         0.        ]
#  [0.8576867  0.14231332 0.         0.        ]
#  [0.85875469 0.14124528 0.         0.        ]
#  [0.86398637 0.13601355 0.         0.        ]
#  [0.87950647 0.12049348 0.         0.        ]
#  [0.88630772 0.11369232 0.         0.        ]
#  [0.88676667 0.11323328 0.         0.        ]
#  [0.89325672 0.1067432  0.         0.        ]
#  [0.8956331  0.10436688 0.         0.        ]
#  [0.9005968  0.09940322 0.         0.        ]
#  [0.90989584 0.09010422 0.         0.        ]
#  [0.91645932 0.08354068 0.         0.        ]]

# %% [markdown]
# P_target         is the real amount of positives
# N_target         is the real amount of negatives
# P_predicted      is the amount of positives predicted
# N_predicted      is the amount of negatives predicted

# %%
P_target = np.sum(y_test)
N_target = num_test_patterns - P_target

# At the beggining of ROC contruction all patterns are predicted as false because the thresold is maximun

TP = 0              #labeled 1  predicted 1
FN = P_target       #labeled 1  predicted 0
FP = 0              #labeled 0  predicted 1 
TN = N_target       #labeled 1 predicted 0

x = []
y = []

TPR = TP/(TP + FN)
FPR = FP/(FP + TN)
x.append(FPR)
y.append(TPR)

target = inference_sorted[:, 3]
predicted = inference_sorted[:, 2]
for i in range(num_test_patterns):

    if(target[i] == 1):
        TP += 1
        FN -= 1
    else:
        TN -= 1
        FP += 1
    
    TPR = TP/(TP + FN)
    FPR = FP/(FP + TN)
    x.append(FPR)
    y.append(TPR)

# %%
fig, ax = plt.subplots()
plt.title('ROC curve')
ax.set_ylabel('TPR or sensitivity') 
ax.set_xlabel('FPR (1 - specificity)') 
plt.scatter(x, y)

# %%
AUC = 0
for i in range(2, num_test_patterns):
    AUC += (x[i] - x[i-1])*(y[i] + y[i-1])/2

print(AUC)
# Out:
# 0.9684343434343434
